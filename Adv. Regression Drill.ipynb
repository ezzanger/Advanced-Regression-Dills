# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model
from sklearn import preprocessing
# %matplotlib inline
sns.set_style('white')
import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from sklearn.decomposition import PCA 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report

# %%
crime2014 = pd.read_csv(r'C://Users/ezzan/Downloads/Table_8_Offenses_Known_to_Law_Enforcement_by_New_York_by_City_2014.csv')

crime2014.drop(['Violent\ncrime','Property\ncrime','Motor\nvehicle\ntheft','Murder and\nnonnegligent\nmanslaughter', 'Rape\n(legacy\ndefinition)2', 'Rape\n(revised\ndefinition)1','Aggravated\nassault','Property\ncrime', 'Arson3', 'Larceny-\ntheft', 'Motor\nvehicle\ntheft'], axis=1)
crime2014['City']= crime2014['City'].apply(lambda x: str(x).replace('4', ''))
crime2014
# Out:
#                                                   City Population  \
# 0                                        Adams Village      1,851
# 1                             Addison Town and Village      2,568
# 2                                        Afton Village        820
# 3                                        Akron Village      2,842
# 4                                               Albany     98,595
# 5                                       Albion Village      5,872
# 6                               Alexandria Bay Village      1,107
# 7                                       Alfred Village      4,032
# 8                                     Altamont Village      1,723
# 9                                         Amherst Town    118,860
# 10                      Amity Town and Belmont Village      2,250
# 11                                  Amityville Village      9,509
# 12                                           Amsterdam     18,099
# ...

# %%
crime2014.tail(20)
crime2014 = crime2014[0:368]
crime2014= crime2014.fillna(value=0)
crime2014 = crime2014.drop(227)

# %%
crime2014['Murder'] = crime2014[['Murder and\nnonnegligent\nmanslaughter']]
crime2014['Robbery'] = crime2014[['Robbery']]
crime2014['Property_Crime'] = crime2014[['Property\ncrime']]
crime2014['Violent_Crime'] = crime2014[['Violent\ncrime']]
crime2014['Rape'] = crime2014[['Rape\n(revised\ndefinition)1']]
crime2014['Agg_Assault'] = crime2014[['Aggravated\nassault']]
crime2014['Motor_Theft'] =crime2014['Motor\nvehicle\ntheft']
crime2014['Arson']= crime2014['Arson3']
crime2014['Larceny']=crime2014['Larceny-\ntheft']
crime2014
# Out:
#                                City Population Violent\ncrime  \
# 0                     Adams Village      1,851              0
# 1          Addison Town and Village      2,568              2
# 2                     Afton Village        820              0
# 3                     Akron Village      2,842              1
# 4                            Albany     98,595            802
# 5                    Albion Village      5,872             26
# 6            Alexandria Bay Village      1,107              0
# 7                    Alfred Village      4,032             11
# 8                  Altamont Village      1,723              1
# 9                      Amherst Town    118,860            128
# 10   Amity Town and Belmont Village      2,250              0
# 11               Amityville Village      9,509             12
# 12                        Amsterdam     18,099             27
# 13                 Angelica Village        846              1
# ...

# %%
crime2014['Population'] = crime2014.Population.str.replace(',','')
crime2014['Property_Crime'] = crime2014.Property_Crime.str.replace(',','')
crime2014['Robbery'] = crime2014.Robbery.str.replace(',','')
crime2014['Violent_Crime'] = crime2014.Violent_Crime.str.replace(',','')
crime2014['Rape']= crime2014.Rape.str.replace(',','')
crime2014['Agg_Assault']= crime2014.Agg_Assault.str.replace(',','')
crime2014['Motor_Theft']=crime2014.Motor_Theft.str.replace(',','')
crime2014['Larceny']=crime2014.Larceny.str.replace(',','')
crime2014['Burglary']=crime2014.Burglary.str.replace(',','')

# %%
crime2014['Population'] = pd.to_numeric(crime2014['Population'])
crime2014['Robbery'] = pd.to_numeric(crime2014['Robbery'])
crime2014['Murder'] = pd.to_numeric(crime2014['Murder'])
crime2014['Property_Crime'] = pd.to_numeric(crime2014['Property_Crime'])
crime2014['Violent_Crime']= pd.to_numeric(crime2014['Violent_Crime'])
crime2014['Rape']= pd.to_numeric(crime2014['Rape'])
crime2014['Agg_Assault']= pd.to_numeric(crime2014['Agg_Assault'])
crime2014['Motor_Theft']= pd.to_numeric(crime2014['Motor_Theft'])
crime2014['Arson']= pd.to_numeric(crime2014['Arson'])
crime2014['Larceny'] = pd.to_numeric(crime2014['Larceny'])
crime2014['Burglary'] = pd.to_numeric(crime2014['Burglary'])
crime2014['Rape']= crime2014['Rape'].fillna(value=0)

# %%
#crime2014['Murder'] = np.where(crime2014['Murder'] >= 1, 1, 0)
#crime2014['Robbery'] = np.where(crime2014['Robbery'] >= 1, 1, 0)
#crime2014['Burglary'] = np.where(crime2014['Burglary'] >= 1, 1, 0)
#crime2014['Agg_Assault'] = np.where(crime2014['Agg_Assault'] >= 1, 1, 0)
#crime2014['Motor_Theft'] = np.where(crime2014['Motor_Theft'] >= 1, 1, 0)
#crime2014['Larceny'] = np.where(crime2014['Larceny'] >= 1, 1, 0)
#crime2014['Rape'] = np.where(crime2014['Rape'] >=1, 1, 0)
#crime2014['Arson'] = np.where(crime2014['Arson'] >=1, 1, 0)
#crime2014['Property_Crime']= np.where(crime2014['Property_Crime'] >=1, 1, 0)

crime2014['Violent_Crime']= np.where(crime2014['Violent_Crime'] >=1, 1, 0)

# %%
crime2014.head()
# Out:
#                        City  Population Violent\ncrime  \
# 0             Adams Village        1851              0
# 1  Addison Town and Village        2568              2
# 2             Afton Village         820              0
# 3             Akron Village        2842              1
# 4                    Albany       98595            802
#
#    Murder and\nnonnegligent\nmanslaughter Rape\n(revised\ndefinition)1  \
# 0                                     0.0                            0
# 1                                     0.0                            0
# 2                                     0.0                            0
# 3                                     0.0                            0
# 4                                     8.0                           54
#
#    Rape\n(legacy\ndefinition)2  Robbery Aggravated\nassault Property\ncrime  \
# 0                          0.0        0                   0              11
# ...

# %% [markdown]
# In order to create more dataset we will get rid of all cities with population above 100,000

# %%
crime2014.sort_values("Population", ascending= False)
crime2014.drop(38)
crime2014.drop(283)
crime2014.drop(366)
crime2014.drop(326)
crime2014.drop(9)
# Out:
#                                City  Population Violent\ncrime  \
# 0                     Adams Village        1851              0
# 1          Addison Town and Village        2568              2
# 2                     Afton Village         820              0
# 3                     Akron Village        2842              1
# 4                            Albany       98595            802
# 5                    Albion Village        5872             26
# 6            Alexandria Bay Village        1107              0
# 7                    Alfred Village        4032             11
# 8                  Altamont Village        1723              1
# 10   Amity Town and Belmont Village        2250              0
# 11               Amityville Village        9509             12
# 12                        Amsterdam       18099             27
# 13                 Angelica Village         846              1
# 14                   Arcade Village        2030              0
# ...

# %%
crime2014['Violent_Crime']
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
# 5      1
# 6      0
# 7      1
# 8      1
# 9      1
# 10     0
# 11     1
# 12     1
# 13     1
# 14     0
# 15     1
# 16     0
# 17     0
# 18     1
# 19     1
# 20     1
# 21     1
# 22     1
# 23     1
# 24     1
# 25     1
# 26     1
# 27     0
# 28     1
# 29     0
#       ..
# 338    1
# 339    1
# 340    1
# 341    1
# 342    1
# 343    1
# 344    1
# 345    1
# 346    1
# 347    1
# 348    1
# 349    1
# 350    1
# 351    1
# 352    1
# 353    1
# 354    1
# 355    1
# 356    1
# 357    1
# 358    1
# 359    1
# 360    1
# 361    0
# 362    1
# 363    0
# 364    1
# 365    1
# 366    1
# 367    1
# Name: Violent_Crime, Length: 367, dtype: int32

# %%
#bigcity = crime2014.loc[lambda crime2014: crime2014['Population'] > 50000, :]
#smallcity= crime2014.loc[lambda crime2014: crime2014['Population'] < 50000, :]
crime2014['big_city']= crime2014['Population'].apply(lambda x:1 if x >10000 else 0)
#crime2013['small_city'] = np.where(crime2013['smallcity'] < 100000, 1, 0)
#crime2013['big_city'] = np.where(crime2013['bigcity'] >= 100000, 1, 0)

# %%
crime2014.tail(120)
crime2014= crime2014.fillna(value=0)
crime2014
# Out:
#      level_0  index                            City  Population  \
# 0          0      0                   Adams Village        1851
# 1          1      1        Addison Town and Village        2568
# 2          2      2                   Afton Village         820
# 3          3      3                   Akron Village        2842
# 4          4      4                          Albany       98595
# 5          5      5                  Albion Village        5872
# 6          6      6          Alexandria Bay Village        1107
# 7          7      7                  Alfred Village        4032
# 8          8      8                Altamont Village        1723
# 9          9      9                    Amherst Town      118860
# 10        10     10  Amity Town and Belmont Village        2250
# 11        11     11              Amityville Village        9509
# 12        12     12                       Amsterdam       18099
# 13        13     13                Angelica Village         846
# ...

# %%
crime2014['big_city'].value_counts()
# Out:
# 0    234
# 1    133
# Name: big_city, dtype: int64

# %%
crime2014.describe()
# Out:
#           level_0       index     Population  \
# count  367.000000  367.000000     367.000000
# mean   183.000000  183.381471   14925.983651
# std    106.088014  106.497577   26596.983712
# min      0.000000    0.000000      79.000000
# 25%     91.500000   91.500000    2646.500000
# 50%    183.000000  183.000000    6581.000000
# 75%    274.500000  275.500000   15325.000000
# max    366.000000  367.000000  258419.000000
#
#        Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# count                              367.000000                    367.000000
# mean                                 0.553134                      3.653951
# std                                  3.691933                     15.555388
# min                                  0.000000                      0.000000
# 25%                                  0.000000                      0.000000
# 50%                                  0.000000                      0.000000
# ...

# %%
crime2014 = crime2014.apply(lambda x: pd.to_numeric(x,errors='ignore'))

# %%
 X_train, X_test, y_train, y_test = train_test_split(crime2014.iloc[:,:-1], crime2014.Violent_Crime, test_size=0.4, random_state=42)

# %%
crime2014['Motor_Theft1']= (crime2014['Motor_Theft'].apply(lambda x:1 if x > 13 else 0))
crime2014['Rob1']= (crime2014['Robbery'].apply(lambda x:1 if x > 15 else 0))

# %%
crime2014['BigCityCrime']=(np.where(crime2014['big_city']==1, 1,0)) & (np.where(crime2014['Rob1']==1, 1, 0)) & (np.where(crime2014['Motor_Theft1']==1, 1, 0))

# %%
len(crime2014[crime2014['big_city']==1])
# Out:
# 133

# %%
crime2014['BigCityCrime'].value_counts()
# Out:
# 0    334
# 1     33
# Name: BigCityCrime, dtype: int64

# %%
pd.crosstab([crime2014['BigCityCrime'], crime2014['Rob1']], crime2014['Motor_Theft1'], margins=True)
# Out:
# Motor_Theft1         0   1  All
# BigCityCrime Rob1
# 0            0     313  10  323
#              1      11   0   11
# 1            1       0  33   33
# All                324  43  367

# %%
X = crime2014.drop(['BigCityCrime', 'Population','Motor\nvehicle\ntheft', 'Larceny', 'Motor_Theft', 'Robbery'], 1)
X = pd.get_dummies(X)
X_scaled = StandardScaler().fit_transform(X)
X = pd.DataFrame(X_scaled, index=X.index, columns=X.columns)
Y = crime2014['BigCityCrime']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True)

# %%
X
# Out:
#       level_0     index  Murder and\nnonnegligent\nmanslaughter  \
# 0   -1.727338 -1.724282                               -0.150027
# 1   -1.717899 -1.714879                               -0.150027
# 2   -1.708460 -1.705476                               -0.150027
# 3   -1.699021 -1.696074                               -0.150027
# 4   -1.689582 -1.686671                                2.019818
# 5   -1.680143 -1.677268                               -0.150027
# 6   -1.670704 -1.667865                               -0.150027
# 7   -1.661265 -1.658463                                0.121204
# 8   -1.651826 -1.649060                               -0.150027
# 9   -1.642387 -1.639657                                0.121204
# 10  -1.632948 -1.630255                               -0.150027
# 11  -1.623509 -1.620852                               -0.150027
# 12  -1.614070 -1.611449                               -0.150027
# 13  -1.604631 -1.602047                               -0.150027
# ...

# %%
lr = LogisticRegression(C=1e9)


# Fit the model.
fit = lr.fit(X, Y)

# Display.
print('Coefficients')
print(fit.coef_)
print(fit.intercept_)
pred_y_sklearn = lr.predict(X)

print('\n Accuracy by admission status')
print(pd.crosstab(pred_y_sklearn, Y))

print('\n Percentage accuracy')
print(lr.score(X, Y))
# Out:
# Coefficients
# [[ 5.68852837e-02  5.66455796e-02  6.96144347e-02  2.14637831e-01
#   -4.09098652e-02  2.41712058e-01  2.07910931e-01  1.60786788e-01
#    6.96144347e-02  3.45350371e-01  1.04746811e-01  2.14637831e-01
#    2.69573371e-01  1.60786788e-01  3.86778765e-01  3.27571661e-01
#    1.03276271e+00  9.82104419e-01 -2.75154350e-03 -6.94353445e-03
#   -5.34316403e-03 -1.02821371e-02  1.34662945e-01  2.50483124e-03
#   -1.34276728e-03 -1.06698647e-02 -9.08561682e-03  1.57781495e-01
#   -3.07865633e-03 -1.29541906e-02 -2.40745649e-02 -1.06824947e-02
#   -8.48119774e-03 -1.07113872e-02 -6.35963087e-03 -9.37269997e-03
#   -9.79551123e-03 -1.21219552e-02 -8.73065165e-03 -2.83987437e-02
#   -8.47169795e-03 -1.22133406e-01 -2.88071549e-02 -2.77345531e-02
#    1.43658076e-01 -6.66758733e-03 -2.27547886e-02 -4.90720679e-03
#   -1.24464026e-02 -8.50664944e-03 -5.14141061e-03 -8.70819789e-03
#   -8.14486844e-02 -5.05894915e-03 -1.01583511e-02 -1.31572727e-03
# ...

# %%
logisticregression = LogisticRegression(C=1e9)

# Fit the model.
fit = logisticregression.fit(X_train, Y_train)
predict_train = fit.predict(X_train)

#Summarize.
print(classification_report(Y_train, predict_train))

# Cross-validate.
score = cross_val_score(logisticregression, X_train, Y_train, cv=5)

print(fit.score(X_train,Y_train))
print('\n Accuracy scores:')
print(score)
print('\n Average score:')
print(sum(score)/5)
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       269
#           1       1.00      1.00      1.00        24
#
# avg / total       1.00      1.00      1.00       293
#
# 1.0
#
#  Accuracy scores:
# [0.54237288 0.45762712 0.42372881 0.38983051 0.38596491]
#
#  Average score:
# 0.43990484686292

# %%
co_dict = {'features': X_train.columns.values, 'coefficients': fit.coef_[0]}
ranked_co = pd.DataFrame(data=co_dict)
ranked_co['coef_absolute'] = abs(ranked_co['coefficients'])
ranked_co = ranked_co.sort_values('coef_absolute', ascending=False)
print(ranked_co)
# Out:
#                                    features  coefficients  coef_absolute
# 17                                     Rob1      1.040787       1.040787
# 16                             Motor_Theft1      0.936205       0.936205
# 14                                  Larceny      0.621409       0.621409
# 9                            Property_Crime      0.578657       0.578657
# 957                       Larceny-\ntheft_8      0.570115       0.570115
# 12                              Agg_Assault      0.547461       0.547461
# 5                                  Burglary      0.471753       0.471753
# 884                      Larceny-\ntheft_37      0.464859       0.464859
# 423                       Violent\ncrime_34      0.464859       0.464859
# 937                      Larceny-\ntheft_63      0.464859       0.464859
# 435                       Violent\ncrime_47      0.437801       0.437801
# 3              Rape\n(revised\ndefinition)1      0.434378       0.434378
# ...

# %%
y_pred = fit.predict(X_test)
print('Test set accuracy: ', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Test set accuracy:  0.2972972972972973
#              precision    recall  f1-score   support
#
#           0       0.95      0.27      0.42        70
#           1       0.06      0.75      0.10         4
#
# avg / total       0.90      0.30      0.40        74

# %% [markdown]
# # Ridge Regression

# %%
# Declare and fit the ridge model.
def log_ridge_run(X_train, y_train, c):
    ridge = LogisticRegression(C=c, penalty='l2', fit_intercept=False)
    ridge.fit(X_train, y_train)   
    print('Ridge Regression results:\n')
    print('Regularization: ', c)
    print('Accuracy, 5 folds: ', cross_val_score(ridge, X_train, y_train, cv=5))
    avg_score = cross_val_score(ridge, X_train, y_train, cv=5).mean()
    print('Average CV score: ', avg_score)
    y_pred = ridge.predict(X_train)
    print('Accuracy, test:\n ', classification_report(y_train, y_pred))
    return avg_score

# %%
def log_ridge_tune(X_train, 
                 y_train, 
                 C = [.01,.1, 1,3,5]):
    results = pd.DataFrame(columns=['Regularization','Accuracy'])
    results['Regularization'] = C
    results = results.set_index('Regularization')
    accuracy = []
    for c in C:
        score = log_ridge_run(X_train, y_train, c)
        accuracy.append(score)
    results['Accuracy'] = accuracy
    results = results.sort_values('Accuracy', ascending=False)
    return print('Results :\n', results)

# %%
log_ridge_tune(X_train, y_train)
# Out:
# Ridge Regression results:
#
# Regularization:  0.01
# Accuracy, 5 folds:  [0.10169492 0.11864407 0.13559322 0.11864407 0.0877193 ]
# Average CV score:  0.11245911388641097
# Accuracy, test:
#                precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       264
#           1       1.00      1.00      1.00        29
#
# avg / total       1.00      1.00      1.00       293
#
# Ridge Regression results:
#
# Regularization:  0.1
# Accuracy, 5 folds:  [0.10169492 0.11864407 0.11864407 0.13559322 0.0877193 ]
# Average CV score:  0.11245911388641097
# Accuracy, test:
#                precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       264
#           1       1.00      1.00      1.00        29
#
# avg / total       1.00      1.00      1.00       293
#
# Ridge Regression results:
#
# Regularization:  1
# Accuracy, 5 folds:  [0.10169492 0.13559322 0.11864407 0.11864407 0.0877193 ]
# ...

# %% [markdown]
# # Lasso Regression

# %%
def log_lasso_run(X_train, y_train, c):
    lasso = LogisticRegression(C=c, penalty='l1', fit_intercept=False)
    lasso.fit(X_train, y_train)   
    print('Lasso Regression results:\n')
    print('Regularization: ', c)
    print('Accuracy, 5 folds: ', cross_val_score(lasso, X_train, y_train, cv=5))
    avg_score = cross_val_score(lasso, X_train, y_train, cv=5).mean()
    print('Average CV score: ', avg_score)
    y_pred = lasso.predict(X_train)
    print('Accuracy, test:\n ', classification_report(y_train, y_pred))
    return avg_score

def log_lasso_tune(X_train, 
                 y_train, 
                 C = [0.1, 1, 3, 5]):#
    results = pd.DataFrame(columns=['Regularization','Accuracy'])
    results['Regularization'] = C
    results = results.set_index('Regularization')
    accuracy = []
    for c in C:
        score = log_lasso_run(X_train, y_train, c)
        accuracy.append(score)
    results['Accuracy'] = accuracy
    results = results.sort_values('Accuracy', ascending=False)
    return print('Results :\n', results)

# %%
log_lasso_tune(X_train, y_train)
# Out:
# Lasso Regression results:
#
# Regularization:  0.1
# Accuracy, 5 folds:  [0.86440678 0.81355932 0.84745763 0.76271186 0.8245614 ]
# Average CV score:  0.8225393993458223
# Accuracy, test:
#                precision    recall  f1-score   support
#
#           0       1.00      0.98      0.99       264
#           1       0.88      1.00      0.94        29
#
# avg / total       0.99      0.99      0.99       293
#
# Lasso Regression results:
#
# Regularization:  1
# Accuracy, 5 folds:  [0.86440678 0.79661017 0.83050847 0.81355932 0.80701754]
# Average CV score:  0.8224204579244722
# Accuracy, test:
#                precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       264
#           1       1.00      1.00      1.00        29
#
# avg / total       1.00      1.00      1.00       293
#
# Lasso Regression results:
#
# Regularization:  3
# Accuracy, 5 folds:  [0.86440678 0.79661017 0.84745763 0.81355932 0.80701754]
# ...

# %%
lasso = LogisticRegression(C=50, penalty='l1', fit_intercept=False)
lasso.fit(X_train, y_train) 

co_dict = {'features': X_train.columns.values, 'coefficients': lasso.coef_[0]}
ranked_co = pd.DataFrame(data=co_dict)
ranked_co['coef_absolute'] = abs(ranked_co['coefficients'])
ranked_co = ranked_co.sort_values('coef_absolute', ascending=False)
print(ranked_co)
# Out:
#                            features  coefficients  coef_absolute
# 14                      Agg_Assault     17.407925      17.407925
# 19                     Motor_Theft1      5.552165       5.552165
# 6                           Robbery      5.284353       5.284353
# 20                             Rob1      3.882678       3.882678
# 8             Motor\nvehicle\ntheft      2.570367       2.570367
# 15                      Motor_Theft      2.458418       2.458418
# 916             Larceny-\ntheft_497     -0.494648       0.494648
# 294               City_Poughkeepsie     -0.456387       0.456387
# 447               Violent\ncrime_55     -0.448206       0.448206
# 726             Property\ncrime_668     -0.410272       0.410272
# 923             Larceny-\ntheft_524     -0.378403       0.378403
# 305                       City_Rome     -0.372534       0.372534
# 479         Aggravated\nassault_147     -0.371099       0.371099
# ...

# %%
y_pred= lasso.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.918918918918919
#              precision    recall  f1-score   support
#
#           0       1.00      0.91      0.95        65
#           1       0.60      1.00      0.75         9
#
# avg / total       0.95      0.92      0.93        74

# %%
graphdf = pd.DataFrame(columns=['lambda', 'ridge-R2','lasso-R2'])

lams = [1,3,5]

for lam in lams:
    ridge = linear_model.Ridge(alpha=lam, fit_intercept=False)
    ridge.fit(X_test, y_train)
    
    lasso = linear_model.Lasso(alpha=lam)
    lasso.fit(X_test, y_train)
    
    new_row = pd.DataFrame([[lam, ridge.score(X_train2, Y_train), lasso.score(X_train2, Y_train)]],
                           columns=['lambda', 'ridge-R2','lasso-R2'])
    graphdf = graphdf.append(new_row, ignore_index=True)
    
    
plt.plot(graphdf['lambda'], graphdf['ridge-R2'], c='g', label='Ridge-R2 by lambda')
plt.plot(graphdf['lambda'], graphdf['lasso-R2'], c='r', label='Lasso-R2 by lambda')
plt.xlabel('lambda')
plt.ylabel('R-squared')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-184-add16d656917> in <module>()
#       6 for lam in lams:
#       7     ridge = linear_model.Ridge(alpha=lam, fit_intercept=False)
# ----> 8     ridge.fit(X_test, y_train)
#       9
#      10     lasso = linear_model.Lasso(alpha=lam)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py in fit(self, X, y, sample_weight)
#     663         self : returns an instance of self.
#     664         """
# --> 665         return super(Ridge, self).fit(X, y, sample_weight=sample_weight)
#     666
#     667
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py in fit(self, X, y, sample_weight)
#     481
#     482         X, y = check_X_y(X, y, ['csr', 'csc', 'coo'], dtype=_dtype,
# --> 483                          multi_output=True, y_numeric=True)
#     484
# ...
