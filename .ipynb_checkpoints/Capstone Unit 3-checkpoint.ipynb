# %%
import numpy as np
import pylab
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.ticker as mtick
# %matplotlib inline
import datetime
from datetime import date
import seaborn as sb
import time
import scipy.stats as stats
from scipy.stats import mstats
from scipy.stats import ttest_ind
from scipy import stats
import seaborn as sns
sns.set_style("whitegrid")
sns.color_palette("Set2", 10)
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
Batting = pd.read_csv('/Users/ezzan/Downloads/python_drills/Batting.csv')
Pitching = pd.read_csv('/Users/ezzan/Downloads/python_drills/Pitching.csv')
Salary= pd.read_csv('/Users/ezzan/Downloads/python_drills/Salaries.csv')
Award = pd.read_csv('/Users/ezzan/Downloads/python_drills/AwardsPlayers.csv')
Team = pd.read_csv('/Users/ezzan/Downloads/python_drills/Teams.csv')
HOF = pd.read_csv('/Users/ezzan/Downloads/python_drills/HallOfFame.csv')
AllStar= pd.read_csv('/Users/ezzan/Downloads/python_drills/AllstarFull.csv')
Fielding =pd.read_csv('/Users/ezzan/Downloads/python_drills/Fielding.csv')
Full =pd.read_csv('/Users/ezzan/Downloads/python_drills/Master.csv')
Appearances = pd.read_csv('/Users/ezzan/Downloads/python_drills/Appearances.csv')
Awards = pd.read_csv('/Users/ezzan/Downloads/python_drills/AwardsPlayers.csv')

# %%
HOF= HOF.sort_values('playerID')
HOF
# Out:
#        playerID  yearid          votedBy  ballots  needed  votes inducted  \
# 2860  aaronha01    1982            BBWAA    415.0   312.0  406.0        Y
# 3743  abbotji01    2005            BBWAA    516.0   387.0   13.0        N
# 1305  adamsba01    1953            BBWAA    264.0   198.0   17.0        N
# 1444  adamsba01    1955            BBWAA    251.0   189.0   24.0        N
# 1390  adamsba01    1954            BBWAA    252.0   189.0   13.0        N
# 1236  adamsba01    1952            BBWAA    234.0   176.0    9.0        N
# 1144  adamsba01    1951            BBWAA    226.0   170.0   12.0        N
# 1052  adamsba01    1950            BBWAA    168.0   126.0    6.0        N
# 146   adamsba01    1937            BBWAA    201.0   151.0    8.0        N
# 826   adamsba01    1948            BBWAA    121.0    91.0    4.0        N
# 770   adamsba01    1947            BBWAA    161.0   121.0   22.0        N
# 697   adamsba01    1946  Nominating Vote    202.0     NaN    6.0        N
# 574   adamsba01    1945            BBWAA    247.0   186.0    7.0        N
# 497   adamsba01    1942            BBWAA    233.0   175.0   11.0        N
# 384   adamsba01    1939            BBWAA    274.0   206.0   11.0        N
# 259   adamsba01    1938            BBWAA    262.0   197.0   11.0        N
# 955   adamsba01    1949            BBWAA    153.0   115.0    5.0        N
# 2108  adamsbo03    1966            BBWAA    302.0   227.0    1.0        N
# 1855  adamssp01    1960            BBWAA    269.0   202.0    1.0        N
# 1706  adamssp01    1958            BBWAA    266.0   200.0    1.0        N
# 2738   ageeto01    1979            BBWAA    432.0   324.0    0.0        N
# 3776  aguilri01    2006            BBWAA    520.0   390.0    3.0        N
# 2788   akerja01    1980            BBWAA    385.0   289.0    0.0        N
# 3424  alexado01    1995            BBWAA    460.0   345.0    0.0        N
# 228   alexape01    1938            BBWAA    262.0   197.0  212.0        Y
# 13    alexape01    1936            BBWAA    226.0   170.0   55.0        N
# 113   alexape01    1937            BBWAA    201.0   151.0  125.0        N
# 2739  allenbe01    1979            BBWAA    432.0   324.0    0.0        N
# 3483  allendi01    1997            BBWAA    473.0   353.0   79.0        N
# 2927  allendi01    1983            BBWAA    374.0   281.0   14.0        N
# ...         ...     ...              ...      ...     ...    ...      ...
# 7     youngcy01    1936            BBWAA    226.0   170.0  111.0        N
# 3967  younger01    2012            BBWAA    573.0   430.0    1.0        N
# 1745  youngpe01    1958            BBWAA    266.0   200.0    1.0        N
# 36    youngro01    1936            BBWAA    226.0   170.0   10.0        N
# 806   youngro01    1948            BBWAA    121.0    91.0   19.0        N
# 245   youngro01    1938            BBWAA    262.0   197.0   40.0        N
# 567   youngro01    1945            BBWAA    247.0   186.0   22.0        N
# 1298  youngro01    1953            BBWAA    264.0   198.0   31.0        N
# 2447  youngro01    1972         Veterans      NaN     NaN    NaN        Y
# 1505  youngro01    1956            BBWAA    193.0   145.0   19.0        N
# 1033  youngro01    1950            BBWAA    168.0   126.0   17.0        N
# 938   youngro01    1949          Run Off    187.0     NaN   11.0        N
# 1381  youngro01    1954            BBWAA    252.0   189.0   34.0        N
# 767   youngro01    1947            BBWAA    161.0   121.0   36.0        N
# 688   youngro01    1946  Nominating Vote    202.0     NaN   25.0        N
# 1434  youngro01    1955            BBWAA    251.0   189.0   48.0        N
# 926   youngro01    1949            BBWAA    153.0   115.0   20.0        N
# 489   youngro01    1942            BBWAA    233.0   175.0   44.0        N
# 1218  youngro01    1952            BBWAA    234.0   176.0   34.0        N
# 1132  youngro01    1951            BBWAA    226.0   170.0   34.0        N
# 370   youngro01    1939            BBWAA    274.0   206.0   34.0        N
# 134   youngro01    1937            BBWAA    201.0   151.0   16.0        N
# 3536  yountro01    1999            BBWAA    497.0   373.0  385.0        Y
# 1746  zachato01    1958            BBWAA    266.0   200.0    1.0        N
# 1881  zachato01    1960            BBWAA    269.0   202.0    1.0        N
# 3272  zachrpa01    1991            BBWAA    443.0   333.0    0.0        N
# 3273   zahnge01    1991            BBWAA    443.0   333.0    0.0        N
# 3909  zeileto01    2010            BBWAA    539.0   405.0    0.0        N
# 347   zimmech01    1938            BBWAA    262.0   197.0    1.0        N
# 3182   ziskri01    1989            BBWAA    447.0   336.0    0.0        N
#
#      category needed_note
# 2860   Player         NaN
# 3743   Player         NaN
# 1305   Player         NaN
# 1444   Player         NaN
# 1390   Player         NaN
# 1236   Player         NaN
# 1144   Player         NaN
# 1052   Player         NaN
# 146    Player         NaN
# 826    Player         NaN
# 770    Player         NaN
# 697    Player      Top 20
# 574    Player         NaN
# 497    Player         NaN
# 384    Player         NaN
# 259    Player         NaN
# 955    Player         NaN
# 2108   Player         NaN
# 1855   Player         NaN
# 1706   Player         NaN
# 2738   Player         NaN
# 3776   Player         NaN
# 2788   Player         NaN
# 3424   Player         NaN
# 228    Player         NaN
# 13     Player         NaN
# 113    Player         NaN
# 2739   Player         NaN
# 3483   Player         NaN
# 2927   Player         NaN
# ...       ...         ...
# 7      Player         NaN
# 3967   Player         NaN
# 1745   Player         NaN
# 36     Player         NaN
# 806    Player         NaN
# 245    Player         NaN
# 567    Player         NaN
# 1298   Player         NaN
# 2447   Player         NaN
# 1505   Player         NaN
# 1033   Player         NaN
# 938    Player         1st
# 1381   Player         NaN
# 767    Player         NaN
# 688    Player      Top 20
# 1434   Player         NaN
# 926    Player         NaN
# 489    Player         NaN
# 1218   Player         NaN
# 1132   Player         NaN
# 370    Player         NaN
# 134    Player         NaN
# 3536   Player         NaN
# 1746   Player         NaN
# 1881   Player         NaN
# 3272   Player         NaN
# 3273   Player         NaN
# 3909   Player         NaN
# 347    Player         NaN
# 3182   Player         NaN
#
# [4156 rows x 9 columns]

# %%
Batting.drop(['CS','SH', 'GIDP', 'IBB'], axis=1, inplace=True)

# %%
HOF2 = HOF.loc[lambda HOF: HOF['inducted'] == 'N', :]

# %%
HOF.drop(['needed_note'], axis=1, inplace=True)

# %%
HOF = HOF.loc[lambda HOF: HOF['category'] == 'Player', :]
HOF = HOF.loc[lambda HOF: HOF['inducted'] == 'Y', :]

# %%
#HOF= pd.merge(HOF, Batting, left_index=True, right_index=True, on='playerID', how='outer');
HOF = HOF.loc[lambda HOF: HOF['inducted'] == 'Y', :]
#HOF = HOF.merge(Batting, on='playerID',how='inner')
#HOF= HOF.loc[lambda HOF1: HOF1['category']=='Player']
HOF.head(50)
# Out:
#        playerID  yearid           votedBy  ballots  needed  votes inducted  \
# 2860  aaronha01    1982             BBWAA    415.0   312.0  406.0        Y
# 228   alexape01    1938             BBWAA    262.0   197.0  212.0        Y
# 3913  alomaro01    2011             BBWAA    581.0   436.0  523.0        Y
# 458   ansonca01    1939        Old Timers      NaN     NaN    NaN        Y
# 2952  aparilu01    1984             BBWAA    403.0   303.0  341.0        Y
# 1969  applilu01    1964           Run Off    201.0     NaN  189.0        Y
# 3428  ashburi01    1995          Veterans      NaN     NaN    NaN        Y
# 2582  averiea01    1975          Veterans      NaN     NaN    NaN        Y
# 4120  bagweje01    2017             BBWAA    442.0   332.0  381.0        Y
# 1483  bakerfr01    1955          Veterans      NaN     NaN    NaN        Y
# 2389  bancrda01    1971          Veterans      NaN     NaN    NaN        Y
# 2622  bankser01    1977             BBWAA    383.0   288.0  321.0        Y
# 2390  becklja01    1971          Veterans      NaN     NaN    NaN        Y
# 2541   bellco99    1974      Negro League      NaN     NaN    NaN        Y
# 3142  benchjo01    1989             BBWAA    447.0   336.0  431.0        Y
# 1361  bendech01    1953          Veterans      NaN     NaN    NaN        Y
# 2398  berrayo01    1972             BBWAA    396.0   297.0  339.0        Y
# 4057  biggicr01    2015             BBWAA    549.0   412.0  454.0        Y
# 3914  blylebe01    2011             BBWAA    581.0   436.0  463.0        Y
# 3726  boggswa01    2005             BBWAA    516.0   387.0  474.0        Y
# 2542  bottoji01    1974          Veterans      NaN     NaN    NaN        Y
# 2292  boudrlo01    1970             BBWAA    300.0   225.0  232.0        Y
# 633   bresnro01    1945        Old Timers      NaN     NaN    NaN        Y
# 3535  brettge01    1999             BBWAA    497.0   373.0  488.0        Y
# 2984  brocklo01    1985             BBWAA    395.0   297.0  315.0        Y
# 634   broutda01    1945        Old Timers      NaN     NaN    NaN        Y
# 1014  brownmo01    1949        Old Timers      NaN     NaN    NaN        Y
# 3782  brownra99    2006      Negro League      NaN     NaN    NaN        Y
# 3783  brownwi02    2006      Negro League      NaN     NaN    NaN        Y
# 3467  bunniji01    1996          Veterans      NaN     NaN    NaN        Y
# 740   burkeje01    1946        Old Timers      NaN     NaN    NaN        Y
# 2245  camparo01    1969             BBWAA    340.0   255.0  270.0        Y
# 3229  carewro01    1991             BBWAA    443.0   333.0  401.0        Y
# 1882  careyma01    1961          Veterans      NaN     NaN    NaN        Y
# 3348  carltst01    1994             BBWAA    456.0   342.0  436.0        Y
# 3662  cartega01    2003             BBWAA    496.0   372.0  387.0        Y
# 3562  cepedor01    1999          Veterans      NaN     NaN    NaN        Y
# 741   chancfr01    1946        Old Timers      NaN     NaN    NaN        Y
# 2618  charlos99    1976      Negro League      NaN     NaN    NaN        Y
# 742   chesbja01    1946        Old Timers      NaN     NaN    NaN        Y
# 635   clarkfr01    1945        Old Timers      NaN     NaN    NaN        Y
# 1965  clarkjo01    1963          Veterans      NaN     NaN    NaN        Y
# 2492  clemero01    1973  Special Election      NaN     NaN    NaN        Y
# 0      cobbty01    1936             BBWAA    226.0   170.0  222.0        Y
# 753   cochrmi01    1947             BBWAA    161.0   121.0  128.0        Y
# 351   collied01    1939             BBWAA    274.0   206.0  213.0        Y
# 636   colliji01    1945        Old Timers      NaN     NaN    NaN        Y
# 2338  combsea01    1970          Veterans      NaN     NaN    NaN        Y
# 2619  connoro01    1976          Veterans      NaN     NaN    NaN        Y
# 3784  coopean99    2006      Negro League      NaN     NaN    NaN        Y
#
#      category
# 2860   Player
# 228    Player
# 3913   Player
# 458    Player
# 2952   Player
# 1969   Player
# 3428   Player
# 2582   Player
# 4120   Player
# 1483   Player
# 2389   Player
# 2622   Player
# 2390   Player
# 2541   Player
# 3142   Player
# 1361   Player
# 2398   Player
# 4057   Player
# 3914   Player
# 3726   Player
# 2542   Player
# 2292   Player
# 633    Player
# 3535   Player
# 2984   Player
# 634    Player
# 1014   Player
# 3782   Player
# 3783   Player
# 3467   Player
# 740    Player
# 2245   Player
# 3229   Player
# 1882   Player
# 3348   Player
# 3662   Player
# 3562   Player
# 741    Player
# 2618   Player
# 742    Player
# 635    Player
# 1965   Player
# 2492   Player
# 0      Player
# 753    Player
# 351    Player
# 636    Player
# 2338   Player
# 2619   Player
# 3784   Player

# %%
HOFstats["admitted"] = np.where(HOFstats['inducted'] == 'Y', 1, 0)

# %%
#master1 = master1.loc[lambda master1: master1['category'] == 'Player', :]
#HOF1 = HOF1.loc[lambda HOF1: HOF1['votedBY'] != 'Negro League', :]
MasterID = pd.merge(Batting, HOF, on='playerID')
#HOF= HOF1.sort_values('playerID')
MasterID["avg."]=MasterID.H/MasterID.AB
MasterID["1B"]=(MasterID.H-MasterID["3B"]-MasterID["2B"])
MasterID["OBP"]= (MasterID.H + MasterID.BB + MasterID.HBP ) / (MasterID.AB + MasterID.BB + MasterID.HBP + MasterID.SF)
MasterID["OBP"]= (MasterID.H + MasterID.BB + MasterID.HBP ) / (MasterID.AB + MasterID.BB + MasterID.HBP + MasterID.SF)
MasterID["slug"]=(MasterID["1B"] + 2*MasterID["2B"] + MasterID["3B"]*3 + 4*MasterID.HR)/MasterID.AB
MasterID["OPS"] = MasterID.OBP + MasterID.slug

#HOF.drop(['teamID', 'lgID','ballots','needed', 'votes'], axis=1, inplace=True)
#master1.drop(['BB_y','HBP_y','SF_y','SO_y'])
#HOF1=HOF1.groupby(['playerID'])['HR']
MasterID = MasterID.sort_values('playerID')
MasterID.head(100)
# Out:
#        playerID  yearID  stint teamID lgID    G   AB    R    H  2B    ...     \
# 3246  aaronha01    1962      1    ML1   NL  156  592  127  191  28    ...
# 3244  aaronha01    1963      1    ML1   NL  161  631  121  201  29    ...
# 3245  aaronha01    1957      1    ML1   NL  151  615  118  198  27    ...
# 3247  aaronha01    1958      1    ML1   NL  153  601  109  196  34    ...
# 3248  aaronha01    1961      1    ML1   NL  155  603  115  197  39    ...
# 3249  aaronha01    1971      1    ATL   NL  139  495   95  162  22    ...
# 3250  aaronha01    1964      1    ML1   NL  145  570  103  187  30    ...
# 3251  aaronha01    1956      1    ML1   NL  153  609  106  200  34    ...
# 3238  aaronha01    1970      1    ATL   NL  150  516  103  154  26    ...
# 3239  aaronha01    1969      1    ATL   NL  147  547  100  164  30    ...
# 3240  aaronha01    1973      1    ATL   NL  120  392   84  118  12    ...
# 3252  aaronha01    1959      1    ML1   NL  154  629  116  223  46    ...
# 3242  aaronha01    1955      1    ML1   NL  153  602  105  189  37    ...
# 3243  aaronha01    1965      1    ML1   NL  150  570  109  181  40    ...
# 3230  aaronha01    1976      1    ML4   AL   85  271   22   62   8    ...
# 3231  aaronha01    1975      1    ML4   AL  137  465   45  109  16    ...
# 3237  aaronha01    1960      1    ML1   NL  153  590  102  172  20    ...
# 3236  aaronha01    1968      1    ATL   NL  160  606   84  174  33    ...
# 3235  aaronha01    1954      1    ML1   NL  122  468   58  131  27    ...
# 3234  aaronha01    1966      1    ATL   NL  158  603  117  168  23    ...
# 3241  aaronha01    1967      1    ATL   NL  155  600  113  184  37    ...
# 3233  aaronha01    1974      1    ATL   NL  112  340   47   91  16    ...
# 3232  aaronha01    1972      1    ATL   NL  129  449   75  119  10    ...
# 443   alexape01    1912      1    PHI   NL   46  102    7   19   4    ...
# 441   alexape01    1911      1    PHI   NL   50  138   12   24   5    ...
# 440   alexape01    1919      1    CHN   NL   30   70    6   12   1    ...
# 436   alexape01    1918      1    CHN   NL    3   10    1    1   0    ...
# 438   alexape01    1913      1    PHI   NL   47  103    9   13   4    ...
# 437   alexape01    1926      2    SLN   NL   23   50    1    6   1    ...
# 444   alexape01    1917      1    PHI   NL   47  139   17   30   8    ...
# ...         ...     ...    ...    ...  ...  ...  ...  ...  ...  ..    ...
# 4002  ansonca01    1888      1    CHN   NL  134  515  101  177  20    ...
# 4008  ansonca01    1873      1    PH1  NaN   52  254   53  101   9    ...
# 3999  ansonca01    1880      1    CHN   NL   86  356   54  120  24    ...
# 3991  ansonca01    1893      1    CHN   NL  103  398   70  125  24    ...
# 3990  ansonca01    1890      1    CHN   NL  139  504   95  157  14    ...
# 3989  ansonca01    1889      1    CHN   NL  134  518  100  161  32    ...
# 3988  ansonca01    1885      1    CHN   NL  112  464  100  144  35    ...
# 3987  ansonca01    1883      1    CHN   NL   98  413   70  127  36    ...
# 3986  ansonca01    1891      1    CHN   NL  136  540   81  157  24    ...
# 3985  ansonca01    1897      1    CHN   NL  114  424   67  121  17    ...
# 3984  ansonca01    1892      1    CHN   NL  146  559   62  152  25    ...
# 3992  ansonca01    1879      1    CHN   NL   51  227   40   72  20    ...
# 3993  ansonca01    1871      1    RC1  NaN   25  120   29   39  11    ...
# 3994  ansonca01    1875      1    PH1  NaN   69  326   84  106  15    ...
# 4001  ansonca01    1878      1    CHN   NL   60  261   55   89  12    ...
# 3995  ansonca01    1896      1    CHN   NL  108  402   72  133  18    ...
# 4000  ansonca01    1877      1    CHN   NL   59  255   52   86  19    ...
# 3998  ansonca01    1874      1    PH1  NaN   55  259   51   87   8    ...
# 3997  ansonca01    1895      1    CHN   NL  122  474   87  159  23    ...
# 3996  ansonca01    1884      1    CHN   NL  112  475  108  159  30    ...
# 3112  aparilu01    1965      1    BAL   AL  144  564   67  127  20    ...
# 3116  aparilu01    1963      1    BAL   AL  146  601   73  150  18    ...
# 3115  aparilu01    1962      1    CHA   AL  153  581   72  140  23    ...
# 3129  aparilu01    1970      1    CHA   AL  146  552   86  173  29    ...
# 3128  aparilu01    1969      1    CHA   AL  156  599   77  168  24    ...
# 3127  aparilu01    1960      1    CHA   AL  153  600   86  166  20    ...
# 3126  aparilu01    1966      1    BAL   AL  151  659   97  182  25    ...
# 3125  aparilu01    1961      1    CHA   AL  156  625   90  170  24    ...
# 3113  aparilu01    1971      1    BOS   AL  125  491   56  114  23    ...
# 3123  aparilu01    1964      1    BAL   AL  146  578   93  154  20    ...
#
#          votedBy  ballots  needed  votes  inducted  category   1B       OBP  \
# 3246       BBWAA    415.0   312.0  406.0         Y    Player  157  0.389805
# 3244       BBWAA    415.0   312.0  406.0         Y    Player  168  0.390756
# 3245       BBWAA    415.0   312.0  406.0         Y    Player  165  0.377778
# 3247       BBWAA    415.0   312.0  406.0         Y    Player  158  0.385542
# 3248       BBWAA    415.0   312.0  406.0         Y    Player  148  0.380597
# 3249       BBWAA    415.0   312.0  406.0         Y    Player  137  0.410122
# 3250       BBWAA    415.0   312.0  406.0         Y    Player  155  0.392744
# 3251       BBWAA    415.0   312.0  406.0         Y    Player  152  0.364885
# 3238       BBWAA    415.0   312.0  406.0         Y    Player  127  0.384615
# 3239       BBWAA    415.0   312.0  406.0         Y    Player  131  0.395931
# 3240       BBWAA    415.0   312.0  406.0         Y    Player  105  0.402151
# 3252       BBWAA    415.0   312.0  406.0         Y    Player  170  0.401154
# 3242       BBWAA    415.0   312.0  406.0         Y    Player  143  0.366261
# 3243       BBWAA    415.0   312.0  406.0         Y    Player  140  0.378717
# 3230       BBWAA    415.0   312.0  406.0         Y    Player   54  0.314935
# 3231       BBWAA    415.0   312.0  406.0         Y    Player   91  0.332103
# 3237       BBWAA    415.0   312.0  406.0         Y    Player  141  0.352410
# 3236       BBWAA    415.0   312.0  406.0         Y    Player  137  0.353550
# 3235       BBWAA    415.0   312.0  406.0         Y    Player   98  0.322068
# 3234       BBWAA    415.0   312.0  406.0         Y    Player  144  0.356105
# 3241       BBWAA    415.0   312.0  406.0         Y    Player  144  0.369208
# 3233       BBWAA    415.0   312.0  406.0         Y    Player   75  0.341207
# 3232       BBWAA    415.0   312.0  406.0         Y    Player  109  0.389706
# 443        BBWAA    262.0   197.0  212.0         Y    Player   15       NaN
# 441        BBWAA    262.0   197.0  212.0         Y    Player   18       NaN
# 440        BBWAA    262.0   197.0  212.0         Y    Player   11       NaN
# 436        BBWAA    262.0   197.0  212.0         Y    Player    1       NaN
# 438        BBWAA    262.0   197.0  212.0         Y    Player    8       NaN
# 437        BBWAA    262.0   197.0  212.0         Y    Player    5       NaN
# 444        BBWAA    262.0   197.0  212.0         Y    Player   20       NaN
# ...          ...      ...     ...    ...       ...       ...  ...       ...
# 4002  Old Timers      NaN     NaN    NaN         Y    Player  145       NaN
# 4008  Old Timers      NaN     NaN    NaN         Y    Player   90       NaN
# 3999  Old Timers      NaN     NaN    NaN         Y    Player   95       NaN
# 3991  Old Timers      NaN     NaN    NaN         Y    Player   99       NaN
# 3990  Old Timers      NaN     NaN    NaN         Y    Player  138       NaN
# 3989  Old Timers      NaN     NaN    NaN         Y    Player  122       NaN
# 3988  Old Timers      NaN     NaN    NaN         Y    Player  102       NaN
# 3987  Old Timers      NaN     NaN    NaN         Y    Player   86       NaN
# 3986  Old Timers      NaN     NaN    NaN         Y    Player  125       NaN
# 3985  Old Timers      NaN     NaN    NaN         Y    Player  101       NaN
# 3984  Old Timers      NaN     NaN    NaN         Y    Player  118       NaN
# 3992  Old Timers      NaN     NaN    NaN         Y    Player   51       NaN
# 3993  Old Timers      NaN     NaN    NaN         Y    Player   25       NaN
# 3994  Old Timers      NaN     NaN    NaN         Y    Player   88       NaN
# 4001  Old Timers      NaN     NaN    NaN         Y    Player   75       NaN
# 3995  Old Timers      NaN     NaN    NaN         Y    Player  113       NaN
# 4000  Old Timers      NaN     NaN    NaN         Y    Player   66       NaN
# 3998  Old Timers      NaN     NaN    NaN         Y    Player   76       NaN
# 3997  Old Timers      NaN     NaN    NaN         Y    Player  130       NaN
# 3996  Old Timers      NaN     NaN    NaN         Y    Player  126       NaN
# 3112       BBWAA    403.0   303.0  341.0         Y    Player   97  0.286179
# 3116       BBWAA    403.0   303.0  341.0         Y    Player  124  0.291473
# 3115       BBWAA    403.0   303.0  341.0         Y    Player  112  0.279935
# 3129       BBWAA    403.0   303.0  341.0         Y    Player  141  0.371522
# 3128       BBWAA    403.0   303.0  341.0         Y    Player  139  0.351714
# 3127       BBWAA    403.0   303.0  341.0         Y    Player  139  0.323077
# 3126       BBWAA    403.0   303.0  341.0         Y    Player  149  0.310791
# 3125       BBWAA    403.0   303.0  341.0         Y    Player  142  0.312874
# 3113       BBWAA    403.0   303.0  341.0         Y    Player   91  0.283835
# 3123       BBWAA    403.0   303.0  341.0         Y    Player  131  0.324409
#
#           slug       OPS
# 3246  0.694257  1.084062
# 3244  0.656101  1.046858
# 3245  0.671545  1.049322
# 3247  0.595674  0.981216
# 3248  0.650083  1.030680
# 3249  0.763636  1.173759
# 3250  0.556140  0.948885
# 3251  0.600985  0.965871
# 3238  0.647287  1.031902
# 3239  0.687386  1.083317
# 3240  0.744898  1.147048
# 3252  0.697933  1.099088
# 3242  0.584718  0.950979
# 3243  0.615789  0.994506
# 3230  0.405904  0.720839
# 3231  0.380645  0.712748
# 3237  0.633898  0.986308
# 3236  0.546205  0.899755
# 3235  0.474359  0.796427
# 3234  0.611940  0.968045
# 3241  0.638333  1.007541
# 3233  0.550000  0.891207
# 3232  0.590200  0.979906
# 443   0.303922       NaN
# 441   0.224638       NaN
# 440   0.185714       NaN
# 436   0.100000       NaN
# 438   0.184466       NaN
# 437   0.140000       NaN
# 444   0.330935       NaN
# ...        ...       ...
# 4002  0.522330       NaN
# 4008  0.448819       NaN
# 3999  0.421348       NaN
# 3991  0.384422       NaN
# 3990  0.414683       NaN
# 3989  0.453668       NaN
# 3988  0.476293       NaN
# 3987  0.418886       NaN
# 3986  0.424074       NaN
# 3985  0.367925       NaN
# 3984  0.355993       NaN
# 3992  0.414097       NaN
# 3993  0.466667       NaN
# 3994  0.389571       NaN
# 4001  0.402299       NaN
# 3995  0.405473       NaN
# 4000  0.419608       NaN
# 3998  0.389961       NaN
# 3997  0.426160       NaN
# 3996  0.587368       NaN
# 3112  0.352837  0.639016
# 3116  0.339434  0.630907
# 3115  0.345955  0.625891
# 3129  0.413043  0.784566
# 3128  0.370618  0.722332
# 3127  0.346667  0.669744
# 3126  0.374810  0.685602
# 3125  0.361600  0.674474
# 3113  0.311609  0.595444
# 3123  0.380623  0.705032
#
# [100 rows x 30 columns]

# %%
 
HOFstats = Batting[["playerID", "HR", "RBI","G","H","2B","3B","AB","R","HBP","BB","SF","SO"]]

HOFstats['100Games'] = np.where(HOFstats['G'] >= 100, 1, 0)
HOFstats["avg."]=HOFstats.H/HOFstats.AB
HOFstats["1B"]=(HOFstats.H-HOFstats["3B"]-HOFstats["2B"])
HOFstats["OBP"]= (HOFstats.H + HOFstats.BB + HOFstats.HBP ) / (HOFstats.AB + HOFstats.BB + HOFstats.HBP + HOFstats.SF)
HOFstats["OBP"]= (HOFstats.H + HOFstats.BB + HOFstats.HBP ) / (HOFstats.AB + HOFstats.BB + HOFstats.HBP + HOFstats.SF)
HOFstats["slug"]=(HOFstats["1B"] + 2*HOFstats["2B"] + HOFstats["3B"]*3 + 4*HOFstats.HR)/HOFstats.AB
HOFstats["OPS"] = HOFstats.OBP + HOFstats.slug
#HOFstats["admitted"] = np.where(HOFstats["inducted"] == 'Y', 1, 0)
HOFstats = HOFstats.sort_values('playerID')
#HOFstats.head(100)
# Out:
# C:\Users\ezzan\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\ezzan\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\ezzan\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ezzan\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\ezzan\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ezzan\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
#HOFstats= HOFstats.loc[lambda HOFstats: HOFstats['G'] > 100, :]

# %%
Batting['avg.'] = Batting["H"]/Batting["AB"]
Batting = Batting.sort_values('avg.')
#HOFstats["admitted"] = np.where(HOFstats['inducted'] == 'Y', 1, 0)
#Batting= Batting.loc[lambda Batting: Batting['AB'] > 600, :]
HOFstats= pd.merge(HOF, HOFstats, left_index=True, right_index=True, on='playerID', how='inner');
HOFstats = HOFstats.sort_values('playerID')
#HOFstats.head(100)

# %%
HOFstats1= pd.merge(HOFstats, Batting, left_index=True, right_index=True, on='playerID', how='outer');
HOFstats1 = HOFstats1.sort_values('playerID')
#HOFstats1["admitted"] = np.where(HOFstats['inducted'] == 'Y', 1, 0)
#HOFstats1

# %%
import matplotlib.pyplot as plt
plt.hist(MasterID['HR'].dropna(),bins=20, color = 'red')
plt.xlabel('Hrs Hit by Hall of Famers per season')
# Out:
# Text(0.5,0,'Hrs Hit by Hall of Famers per season')

# %%
plt.hist(MasterID['RBI'].dropna(),bins=100, color = 'green')
plt.xlabel('RBI by Hall of Famers')
# Out:
# Text(0.5,0,'RBI by Hall of Famers')

# %%
plt.hist(MasterID['H'].dropna(),bins=100, color = 'blue')
plt.xlabel('Hit by Hall of Famers')
# Out:
# Text(0.5,0,'Hit by Hall of Famers')

# %%
plt.hist(MasterID['OBP'].dropna(),bins=100, color = 'blue')
plt.xlabel('OBP by Hall of Famers')
# Out:
# Text(0.5,0,'OBP by Hall of Famers')

# %%
plt.hist(MasterID['slug'].dropna(),bins=100, color = 'purple')
plt.xlabel('Slugging Percentage by Hall of Famers per 100 games or more')
# Out:
# Text(0.5,0,'Slugging Percentage by Hall of Famers per 100 games or more')

# %%
plt.hist(HOFstats['OPS'].dropna(),bins=100, color = 'orange')
plt.xlabel('OPS by Hall of Famers per 100 games or more')
# Out:
# Text(0.5,0,'OPS by Hall of Famers per 100 games or more')

# %%
sb.heatmap(HOFstats.corr())

# %%
OPS = []
OPS['playerID']=HOFstats['playerID']
OPS["OPS"]=HOFstats["OPS"]
OPS.groupby('playerID')['OPS']

# %%
OPS = []
OPS["playerID"]= HOFstas['playerID']
OPS["OPS"]= HOFstas["OPS"]

# %%
OPS= OPS.head(50)

# %%
OPS

# %%
#HOF2= pd.merge(HOF2, Batting, left_index=True, right_index=True, on='playerID', how='inner');
#HOF = HOF.loc[lambda HOF: HOF['category'] == 'Player', :]
HOF = pd.merge(HOF,Batting, on='playerID')
HOF= HOF.sort_values("HR")
HOF.tail(100)

# %%
master3= pd.merge(Pitching, HOF1, left_index=True, right_index=True, on='playerID', how='inner');
master3 = master3.loc[lambda master3: master3['category'] == 'Player', :]
master3 = pd.merge(Pitching, HOF1, on='playerID')
master3= master3.sort_values('playerID')
master3.drop(['teamID', 'lgID', 'votedBy', 'ballots','needed', 'votes'], axis=1, inplace=True)
master3

# %% [markdown]
# ## The National Baseball Hall of Fame and Museum is located in Cooperstown, New York and was dedicated in 1939. A baseball player can be elected to the Hall of Fame if they meet the following criteria:
#
# -The player must have competed in at least ten seasons;
#
# -The player has been retired for at least five seasons;
#
# -A screening committee must approve the player’s worthiness to be included on the ballot and most players who played regularly for ten or more years are deemed worthy;
#
# -The player must not be on the ineligible list (that means that the player should not be banned from baseball);
#
# -A player is considered elected if he receives at least 75% of the vote in the election; and
#
# -A player stays on the ballot the following year if they receive at least 5% of the vote and can appear on ballots for a maximum of 10 years.

# %%
HOF
# Out:
#             votedBy  ballots  needed  votes inducted           category
# playerID
# cobbty01      BBWAA    226.0   170.0  222.0        Y             Player
# ruthba01      BBWAA    226.0   170.0  215.0        Y             Player
# wagneho01     BBWAA    226.0   170.0  215.0        Y             Player
# mathech01     BBWAA    226.0   170.0  205.0        Y             Player
# johnswa01     BBWAA    226.0   170.0  189.0        Y             Player
# lajoina01     BBWAA    226.0   170.0  146.0        N             Player
# speaktr01     BBWAA    226.0   170.0  133.0        N             Player
# youngcy01     BBWAA    226.0   170.0  111.0        N             Player
# hornsro01     BBWAA    226.0   170.0  105.0        N             Player
# cochrmi01     BBWAA    226.0   170.0   80.0        N             Player
# sislege01     BBWAA    226.0   170.0   77.0        N             Player
# collied01     BBWAA    226.0   170.0   60.0        N             Player
# colliji01     BBWAA    226.0   170.0   58.0        N             Player
# alexape01     BBWAA    226.0   170.0   55.0        N             Player
# gehrilo01     BBWAA    226.0   170.0   51.0        N             Player
# bresnro01     BBWAA    226.0   170.0   47.0        N             Player
# keelewi01     BBWAA    226.0   170.0   40.0        N             Player
# ansonca01  Veterans     78.0    59.0   39.0        N             Player
# ewingbu01  Veterans     78.0    59.0   39.0        N             Player
# keelewi01  Veterans     78.0    59.0   33.0        N             Player
# wadderu01     BBWAA    226.0   170.0   33.0        N             Player
# youngcy01  Veterans     78.0    59.0   32.0        N             Player
# delahed01  Veterans     78.0    59.0   21.0        N             Player
# foxxji01      BBWAA    226.0   170.0   21.0        N             Player
# walshed01     BBWAA    226.0   170.0   20.0        N             Player
# mcgrajo01  Veterans     78.0    59.0   17.0        N             Player
# delahed01     BBWAA    226.0   170.0   17.0        N             Player
# radboch01  Veterans     78.0    59.0   16.0        N             Player
# traynpi01     BBWAA    226.0   170.0   16.0        N             Player
# kellyki01  Veterans     78.0    59.0   15.0        N             Player
# ...             ...      ...     ...    ...      ...                ...
# clemero02     BBWAA    442.0   332.0  239.0        N             Player
# bondsba01     BBWAA    442.0   332.0  238.0        N             Player
# mussimi01     BBWAA    442.0   332.0  229.0        N             Player
# schilcu01     BBWAA    442.0   332.0  199.0        N             Player
# smithle02     BBWAA    442.0   332.0  151.0        N             Player
# ramirma02     BBWAA    442.0   332.0  105.0        N             Player
# walkela01     BBWAA    442.0   332.0   97.0        N             Player
# mcgrifr01     BBWAA    442.0   332.0   96.0        N             Player
# kentje01      BBWAA    442.0   332.0   74.0        N             Player
# sheffga01     BBWAA    442.0   332.0   59.0        N             Player
# wagnebi02     BBWAA    442.0   332.0   45.0        N             Player
# sosasa01      BBWAA    442.0   332.0   38.0        N             Player
# posadjo01     BBWAA    442.0   332.0   17.0        N             Player
# ordonma01     BBWAA    442.0   332.0    3.0        N             Player
# varitja01     BBWAA    442.0   332.0    2.0        N             Player
# renteed01     BBWAA    442.0   332.0    2.0        N             Player
# wakefti01     BBWAA    442.0   332.0    1.0        N             Player
# morame01      BBWAA    442.0   332.0    0.0        N             Player
# camermi01     BBWAA    442.0   332.0    0.0        N             Player
# rhodear01     BBWAA    442.0   332.0    0.0        N             Player
# sanchfr01     BBWAA    442.0   332.0    0.0        N             Player
# cabreor01     BBWAA    442.0   332.0    0.0        N             Player
# drewj.01      BBWAA    442.0   332.0    0.0        N             Player
# leede02       BBWAA    442.0   332.0    0.0        N             Player
# blakeca01     BBWAA    442.0   332.0    0.0        N             Player
# guillca01     BBWAA    442.0   332.0    0.0        N             Player
# burrepa01     BBWAA    442.0   332.0    0.0        N             Player
# stairma01     BBWAA    442.0   332.0    0.0        N             Player
# seligbu99  Veterans      NaN     NaN    NaN        Y  Pioneer/Executive
# schurjo99  Veterans      NaN     NaN    NaN        Y  Pioneer/Executive
#
# [4156 rows x 6 columns]

# %%
HOF2 = HOF.loc[lambda HOF: HOF['category'] == 'Player', :]
HOF2 = HOF.loc[lambda HOF: HOF['inducted'] == 'N', :]

# %%
HOF2
# Out:
#             votedBy  ballots  needed  votes inducted category
# playerID
# lajoina01     BBWAA    226.0   170.0  146.0        N   Player
# speaktr01     BBWAA    226.0   170.0  133.0        N   Player
# youngcy01     BBWAA    226.0   170.0  111.0        N   Player
# hornsro01     BBWAA    226.0   170.0  105.0        N   Player
# cochrmi01     BBWAA    226.0   170.0   80.0        N   Player
# sislege01     BBWAA    226.0   170.0   77.0        N   Player
# collied01     BBWAA    226.0   170.0   60.0        N   Player
# colliji01     BBWAA    226.0   170.0   58.0        N   Player
# alexape01     BBWAA    226.0   170.0   55.0        N   Player
# gehrilo01     BBWAA    226.0   170.0   51.0        N   Player
# bresnro01     BBWAA    226.0   170.0   47.0        N   Player
# keelewi01     BBWAA    226.0   170.0   40.0        N   Player
# ansonca01  Veterans     78.0    59.0   39.0        N   Player
# ewingbu01  Veterans     78.0    59.0   39.0        N   Player
# keelewi01  Veterans     78.0    59.0   33.0        N   Player
# wadderu01     BBWAA    226.0   170.0   33.0        N   Player
# youngcy01  Veterans     78.0    59.0   32.0        N   Player
# delahed01  Veterans     78.0    59.0   21.0        N   Player
# foxxji01      BBWAA    226.0   170.0   21.0        N   Player
# walshed01     BBWAA    226.0   170.0   20.0        N   Player
# mcgrajo01  Veterans     78.0    59.0   17.0        N   Player
# delahed01     BBWAA    226.0   170.0   17.0        N   Player
# radboch01  Veterans     78.0    59.0   16.0        N   Player
# traynpi01     BBWAA    226.0   170.0   16.0        N   Player
# kellyki01  Veterans     78.0    59.0   15.0        N   Player
# longhe01   Veterans     78.0    59.0   15.0        N   Player
# friscfr01     BBWAA    226.0   170.0   14.0        N   Player
# grovele01     BBWAA    226.0   170.0   12.0        N   Player
# jennihu01  Veterans     78.0    59.0   11.0        N   Player
# rusieam01  Veterans     78.0    59.0   11.0        N   Player
# ...             ...      ...     ...    ...      ...      ...
# guerrvl01     BBWAA    442.0   332.0  317.0        N   Player
# martied01     BBWAA    442.0   332.0  259.0        N   Player
# clemero02     BBWAA    442.0   332.0  239.0        N   Player
# bondsba01     BBWAA    442.0   332.0  238.0        N   Player
# mussimi01     BBWAA    442.0   332.0  229.0        N   Player
# schilcu01     BBWAA    442.0   332.0  199.0        N   Player
# smithle02     BBWAA    442.0   332.0  151.0        N   Player
# ramirma02     BBWAA    442.0   332.0  105.0        N   Player
# walkela01     BBWAA    442.0   332.0   97.0        N   Player
# mcgrifr01     BBWAA    442.0   332.0   96.0        N   Player
# kentje01      BBWAA    442.0   332.0   74.0        N   Player
# sheffga01     BBWAA    442.0   332.0   59.0        N   Player
# wagnebi02     BBWAA    442.0   332.0   45.0        N   Player
# sosasa01      BBWAA    442.0   332.0   38.0        N   Player
# posadjo01     BBWAA    442.0   332.0   17.0        N   Player
# ordonma01     BBWAA    442.0   332.0    3.0        N   Player
# varitja01     BBWAA    442.0   332.0    2.0        N   Player
# renteed01     BBWAA    442.0   332.0    2.0        N   Player
# wakefti01     BBWAA    442.0   332.0    1.0        N   Player
# morame01      BBWAA    442.0   332.0    0.0        N   Player
# camermi01     BBWAA    442.0   332.0    0.0        N   Player
# rhodear01     BBWAA    442.0   332.0    0.0        N   Player
# sanchfr01     BBWAA    442.0   332.0    0.0        N   Player
# cabreor01     BBWAA    442.0   332.0    0.0        N   Player
# drewj.01      BBWAA    442.0   332.0    0.0        N   Player
# leede02       BBWAA    442.0   332.0    0.0        N   Player
# blakeca01     BBWAA    442.0   332.0    0.0        N   Player
# guillca01     BBWAA    442.0   332.0    0.0        N   Player
# burrepa01     BBWAA    442.0   332.0    0.0        N   Player
# stairma01     BBWAA    442.0   332.0    0.0        N   Player
#
# [3839 rows x 6 columns]

# %%
import functools
master1 = functools.reduce(lambda x,y: x.merge(y,on=['playerID']), [HOF,Batting])
master1 = master1.reset_index().groupby("playerID")
#master1.drop(['votedBy','ballots', 'needed','votes'], axis=1, inplace=True)

# %%
master1

# %%
pos_df = pd.DataFrame.from_dict(pos_dict, orient='index')
